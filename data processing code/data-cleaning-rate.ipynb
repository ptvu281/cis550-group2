# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
rate_orig = pd.read_csv('../input/health-insurance-marketplace/Rate.csv')

# %%
rate_orig.head()

# %%
rate = rate_orig[['PlanId','IssuerId','RateEffectiveDate','RateExpirationDate','Age','Tobacco','IndividualRate', 'IndividualTobaccoRate']]
rate.drop_duplicates(inplace=True)
rate.head()

# %%
rate = rate[(rate['Age']=='0-20') | (rate['Age']=='Family Option') | (rate['Age']=='21')]

# %%
rate.loc[rate.Age == '21','Age'] = '21 and over'
rate.head()

# %%
rate['RateEffectiveDate'] = pd.to_datetime(rate['RateEffectiveDate'],infer_datetime_format=True)
rate['RateExpirationDate'] = pd.to_datetime(rate['RateExpirationDate'],infer_datetime_format=True)

# %%
rate = rate[['PlanId','IssuerId','RateEffectiveDate','RateExpirationDate','Age','Tobacco','IndividualRate', 'IndividualTobaccoRate']]
rate.head()

# %%
rate['PlanId'] = rate['PlanId'].apply(lambda x: x + '-00')

# %%
rate.drop_duplicates(inplace=True)

# %%
len(rate)
rate.head()

# %%
rate_cleaned.to_csv('Rate.csv',index=False, na_rep='\\N')

# %%
rate_cleaned = rate.groupby(by=['PlanId','IssuerId','RateEffectiveDate','RateExpirationDate','Age','Tobacco'], as_index=False).mean()

# %%
len(rate_cleaned)

# %%
rate_cleaned['IndividualRate'].unique()

# %%
family_option = rate_orig[['PlanId','RateEffectiveDate','RateExpirationDate','Couple','PrimarySubscriberAndOneDependent', 'PrimarySubscriberAndTwoDependents','PrimarySubscriberAndThreeOrMoreDependents', 'CoupleAndOneDependent','CoupleAndTwoDependents', 'CoupleAndThreeOrMoreDependents']]
family_option.drop_duplicates(inplace=True)
family_option.head()

# %%
family_option = family_option.dropna(how='all',subset=['Couple','PrimarySubscriberAndOneDependent',
       'PrimarySubscriberAndTwoDependents',
       'PrimarySubscriberAndThreeOrMoreDependents', 'CoupleAndOneDependent',
       'CoupleAndTwoDependents', 'CoupleAndThreeOrMoreDependents'])

# %%
rate[rate['PlanId']=='95819TX0010001'].head(100)

# %%
family_option_cleaned = family_option.groupby(by=['PlanId','RateEffectiveDate','RateExpirationDate'], as_index=False).mean()

# %%
family_option_cleaned['PlanId'] = family_option_cleaned['PlanId'].apply(lambda x: x + '-00')

# %%
family_option_cleaned.to_csv('FamilyOption.csv',index=False)

# %%
family_option_cleaned.head()
